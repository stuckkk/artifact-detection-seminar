# %% [markdown]
# - AAREADME.txt Datei Metadaten lesen
# 	- 310 EDF Dateien
# 	- 259 Sessions
# 	- 213 Patienten
# 	- 160.073 Events (ohne Background)
# 	- 42 Dateien mit Epilepsieanfall
# 	- 359.936 Sekunden / 5.998,93 Minuten / 99,98 Stunden Daten
# 	- durchschnittliche Dauer von 1.161,08 Sekunden / 19,35 Minuten / 0,32 Stunden
