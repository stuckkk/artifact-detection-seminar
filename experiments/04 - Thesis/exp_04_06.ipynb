# %% [markdown]
# Dieses Skript erzeugt die Visualisierung für zwei sich zum Teil überlappende Intervalle.

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(figsize=(6, 1))

annot = ax.barh(y=0, width=1, left=0.5, height=1, color='blue', edgecolor='blue', alpha=0.5, label=r'$a \in A$')
pred = ax.broken_barh([(0, 1), (1, 1)], (1, 1), color='red', edgecolor='red', alpha=0.5, label=r'$p \in P$')

ax.get_yaxis().set_visible(False)
# ax.bar_label(annot, labels=[r'$a \in A$'], label_type='center')
# ax.text(x=1, y=1.5, s=r'$p \in P$', ha='center', va='center')
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.legend(loc='lower left')
plt.savefig('output/exp_04_06_iou_example.pdf', bbox_inches='tight')
plt.show()
