# %% [markdown]
# Dieses Skript führt das Preprocessing durch. Dabei werden die Daten geresampled und es wird ein Hoch- sowie Tiefpaß angewendet.

# %%
from utils.filter_and_resample import resample_and_filter_edf_files

resample_and_filter_edf_files(
    dir_path='/home/users/jhischke/tuar_processed',
    target_fs=250,
    hp=0.5,
    #124.9 so that it is really smaller than Nyquist Frequency of 125 Hz
    lp=124.9,
    order=5
)
# Out:
# Resampling files in /home/users/jhischke/tuar_processed: 0it [00:00, ?it/s]
# Resampling files in /home/users/jhischke/tuar_processed/train: 100%|██████████| 320/320 [05:32<00:00,  1.04s/it]
# Resampling files in /home/users/jhischke/tuar_processed/val:  10%|█         | 10/98 [00:17<02:44,  1.87s/it]/home/users/jhischke/miniforge3/envs/artifact-detection/lib/python3.14/site-packages/pyedflib/edfwriter.py:140: UserWarning: Physical maximum for channel 11 (CZ-C4) is 5.6899999999999995, which has 18 chars, however, EDF+ can only save 8 chars, will be truncated to 5.689999, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '
# Resampling files in /home/users/jhischke/tuar_processed/val: 100%|██████████| 98/98 [01:34<00:00,  1.04it/s]
# Resampling files in /home/users/jhischke/tuar_processed/test: 100%|██████████| 118/118 [02:03<00:00,  1.05s/it]
