# %% [markdown]
# Dieses Skript visualisiert die in die Montage umgewandelten EEG Signale, um einen Sanity Check nach der Transformation durchzuführen.

# %%
from utils.visualize_eeg import visualize_eeg_with_artifacts

fig = visualize_eeg_with_artifacts(
    edf_file_path="../../../../tuar_processed/02_tcp_le/aaaaagcs_s002_t000.edf",
    csv_file_path="../../../../tuar_processed/02_tcp_le/aaaaagcs_s002_t000.csv",
    channel='FP2-F8',
    interval_start=558,
    interval_stop=564
)
fig.savefig("output/exp_02_02_artifact_visualization_other_channel.svg")
fig.show()

# %% [markdown]
# - Bemerkungen
#     - Es ist ein anderer Ausschnitt auf der y-Achse als bei dem anderen Plot aus `exp_01_05`. Daher sehen die Daten in dem Kanal volatiler aus.
#
# - Notizen
#     - Die Artefaktannotationen scheinen mir realistisch zu sein. Das Augenartefakt ist wieder bei sehr niedrigen Frequenzen und das Elektrodenartefakt ist ein einziger kurzer Spike.

# %%
from utils.visualize_eeg import visualize_eeg_with_artifacts

fig = visualize_eeg_with_artifacts(
    edf_file_path="../../../../tuar_processed/01_tcp_ar/aaaaaaju_s005_t000.edf",
    csv_file_path="../../../../tuar_processed/01_tcp_ar/aaaaaaju_s005_t000.csv",
    channel='F7-T3',
    interval_start=135,
    interval_stop=150
)
fig.savefig("output/exp_02_02_artifact_visualization_comparison.svg")
fig.show()

# %% [markdown]
# - Notizen
#     - Oben habe ich eine weitere Datei mit einer anderen Montage visualisiert, um einen weiteren Sanity Check durchzuführen.
#     - Die Daten sehen identisch mit denen aus `exp_01_05` aus. Die Transformation scheint daher geklappt zu haben.
