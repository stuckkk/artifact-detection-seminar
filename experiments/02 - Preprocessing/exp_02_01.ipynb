# %% [markdown]
# Dieses Skript wandelt die EDF Dateien des TUAR Datensatzes in ihre jeweilige Montage um.

# %%
from utils.apply_montage import convert_and_store_edf_files

input_path = '/home/users/jhischke/tuar'
output_path = '/home/users/jhischke/tuar_processed'

convert_and_store_edf_files(input_path=input_path, output_path=output_path)
