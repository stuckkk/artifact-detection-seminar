# %% [markdown]
# Dieses Skript visualisiert die Power Spektren nach dem Filtern und Resamplen, um zu überprüfen, dass alles korrekt funktoiniert hat.

# %%
from utils.visualize_eeg import visualize_power_spectrum

fig = visualize_power_spectrum('/home/users/jhischke/tuar_processed/test/aaaaaall_s004_t000.edf', 'F7-T3')
fig.savefig('./output/exp_02_07_power_spectrum_comparison_1.svg')
fig.show()

# %%
fig = visualize_power_spectrum('/home/users/jhischke/tuar_processed/train/aaaaagqb_s003_t002.edf', 'T4-A2')
fig.savefig('./output/exp_02_07_power_spectrum_comparison_2.svg')
fig.show()

# %%
fig = visualize_power_spectrum('/home/users/jhischke/tuar_processed/train/aaaaadao_s001_t003.edf', 'CZ-C4')
fig.savefig('./output/exp_02_07_power_spectrum_comparison_3.svg')
fig.show()

# %%
fig = visualize_power_spectrum('/home/users/jhischke/tuar_processed/test/aaaaacyf_s007_t002.edf', 'P4-O2', ylim=(10e-4, 10e2))
fig.savefig('./output/exp_02_07_power_spectrum_comparison_4.svg')
fig.show()

# %% [markdown]
# Die Power Spektren scheinen noch nicht ganz zu passen.
