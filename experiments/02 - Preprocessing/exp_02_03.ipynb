# %% [markdown]
# Dieses Skript sortiert die `EDF` und `CSV` Dateien nach Aymanes Split.

# %%
from utils.data_splitting import sort_files_by_set, get_mapped_names, remove_seizure_recordings
import os

data_split_file = '../../../EAD/code/preprocessing/data_split.yaml'
name_mappings_file = '../../../EAD/code/molding/name_mappings.csv'

dst_path = '/home/users/jhischke/tuar_processed'

mapped_names = get_mapped_names(data_split_file, name_mappings_file)
sort_files_by_set(mapped_names, dir_path=dst_path)
remove_seizure_recordings(dst_path)
# Out:
# Removing seizure recordings in /home/users/jhischke/tuar_processed: 0it [00:00, ?it/s]
# Removing seizure recordings in /home/users/jhischke/tuar_processed/train: 100%|██████████| 365/365 [00:00<00:00, 12071.03it/s]
# Removing seizure recordings in /home/users/jhischke/tuar_processed/val: 100%|██████████| 98/98 [00:00<00:00, 809137.39it/s]
# Removing seizure recordings in /home/users/jhischke/tuar_processed/test: 100%|██████████| 133/133 [00:00<00:00, 12622.58it/s]

# %% [markdown]
# Die Dateien scheinen richtig sortiert zu sein. Es sind nur Patienten/Dateien mit Seizures unsortiert, was auch so sein sollte.
