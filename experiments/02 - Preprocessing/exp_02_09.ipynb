# %% [markdown]
# Dieses Skript führt die selben Experimente wie in `exp_02_06` durch, allerdings mit den Daten ohne Hochpaß. Dies ist ein Sanity Check für das Preprocessing ohne Hochpaß.

# %%
import pyedflib
import matplotlib.pyplot as plt
from scipy.signal import welch

original_path = '/home/users/jhischke/tuar_processed_backup_before_resampling/test/aaaaaall_s004_t000.edf'
new_path = '/home/users/jhischke/tuar_processed_no_hp/test/aaaaaall_s004_t000.edf'
channel = 'F7-T3'

with pyedflib.EdfReader(original_path) as reader:
    channel_idx = reader.getSignalLabels().index(channel)
    channel_data = reader.readSignal(channel_idx)
    sampling_frequency = reader.getSampleFrequency(channel_idx)
    f, pxx = welch(channel_data, fs=sampling_frequency, nperseg=2048)
    plt.semilogy(f, pxx, label='Original', color='blue')

with pyedflib.EdfReader(new_path) as reader:
    channel_idx = reader.getSignalLabels().index(channel)
    channel_data = reader.readSignal(channel_idx)
    sampling_frequency = reader.getSampleFrequency(channel_idx)
    f, pxx = welch(channel_data, fs=sampling_frequency, nperseg=2048)
    plt.semilogy(f, pxx, label='After resampling/filter', color='orange')

plt.title(f"Power Spektrum des EEG Signals von Kanal {channel}")
plt.xlabel("Frequenz in Hz")
plt.ylabel("Leistung/Frequenz (V²/Hz)")
plt.legend()
plt.savefig('./output/exp_02_09_power_spectrum_comparison_1.svg')
plt.show()

# %%
original_path = '/home/users/jhischke/tuar_processed_backup_before_resampling/train/aaaaagqb_s003_t002.edf'
new_path = '/home/users/jhischke/tuar_processed_no_hp/train/aaaaagqb_s003_t002.edf'
channel = 'T4-A2'

with pyedflib.EdfReader(original_path) as reader:
    channel_idx = reader.getSignalLabels().index(channel)
    channel_data = reader.readSignal(channel_idx)
    sampling_frequency = reader.getSampleFrequency(channel_idx)
    f, pxx = welch(channel_data, fs=sampling_frequency, nperseg=2048)
    plt.semilogy(f, pxx, label='Original', color='blue')

with pyedflib.EdfReader(new_path) as reader:
    channel_idx = reader.getSignalLabels().index(channel)
    channel_data = reader.readSignal(channel_idx)
    sampling_frequency = reader.getSampleFrequency(channel_idx)
    f, pxx = welch(channel_data, fs=sampling_frequency, nperseg=2048)
    plt.semilogy(f, pxx, label='After resampling/filter', color='orange')

plt.title(f"Power Spektrum des EEG Signals von Kanal {channel}")
plt.xlabel("Frequenz in Hz")
plt.ylabel("Leistung/Frequenz (V²/Hz)")
plt.legend()
plt.savefig('./output/exp_02_09_power_spectrum_comparison_2.svg')
plt.show()

# %%
original_path = '/home/users/jhischke/tuar_processed_backup_before_resampling/train/aaaaadao_s001_t003.edf'
new_path = '/home/users/jhischke/tuar_processed_no_hp/train/aaaaadao_s001_t003.edf'
channel = 'CZ-C4'

with pyedflib.EdfReader(original_path) as reader:
    channel_idx = reader.getSignalLabels().index(channel)
    channel_data = reader.readSignal(channel_idx)
    sampling_frequency = reader.getSampleFrequency(channel_idx)
    f, pxx = welch(channel_data, fs=sampling_frequency, nperseg=2048)
    plt.semilogy(f, pxx, label='Original', color='blue')

with pyedflib.EdfReader(new_path) as reader:
    channel_idx = reader.getSignalLabels().index(channel)
    channel_data = reader.readSignal(channel_idx)
    sampling_frequency = reader.getSampleFrequency(channel_idx)
    f, pxx = welch(channel_data, fs=sampling_frequency, nperseg=2048)
    plt.semilogy(f, pxx, label='After resampling/filter', color='orange')

plt.title(f"Power Spektrum des EEG Signals von Kanal {channel}")
plt.xlabel("Frequenz in Hz")
plt.ylabel("Leistung/Frequenz (V²/Hz)")
plt.legend()
plt.savefig('./output/exp_02_09_power_spectrum_comparison_3.svg')
plt.show()

# %%
original_path = '/home/users/jhischke/tuar_processed_backup_before_resampling/test/aaaaacyf_s007_t002.edf'
new_path = '/home/users/jhischke/tuar_processed_no_hp/test/aaaaacyf_s007_t002.edf'
channel = 'P4-O2'

with pyedflib.EdfReader(original_path) as reader:
    channel_idx = reader.getSignalLabels().index(channel)
    channel_data = reader.readSignal(channel_idx)
    sampling_frequency = reader.getSampleFrequency(channel_idx)
    f, pxx = welch(channel_data, fs=sampling_frequency, nperseg=2048)
    plt.semilogy(f, pxx, label='Original', color='blue')

with pyedflib.EdfReader(new_path) as reader:
    channel_idx = reader.getSignalLabels().index(channel)
    channel_data = reader.readSignal(channel_idx)
    sampling_frequency = reader.getSampleFrequency(channel_idx)
    f, pxx = welch(channel_data, fs=sampling_frequency, nperseg=2048)
    plt.semilogy(f, pxx, label='After resampling/filter', color='orange')

plt.title(f"Power Spektrum des EEG Signals von Kanal {channel}")
plt.xlabel("Frequenz in Hz")
plt.ylabel("Leistung/Frequenz (V²/Hz)")
plt.legend()
plt.savefig('./output/exp_02_09_power_spectrum_comparison_4.svg')
plt.show()

# %% [markdown]
# - Notizen
#     - Insbesondere bei Beispiel 3 und 4 ist schön zu sehen, wie die Frequenzanteile ab ca. 120 Hz herausgefiltert werden.
