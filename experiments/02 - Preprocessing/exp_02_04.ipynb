# %% [markdown]
# Dieses Skript visualisiert das Power Spektrum eines EEG Kanals in einem Powerspektrum.

# %%
from utils.visualize_eeg import visualize_power_spectrum

fig = visualize_power_spectrum('/home/users/jhischke/tuar_processed/test/aaaaaall_s004_t000.edf', 'F7-T3')
fig.savefig('./output/exp_02_04_power_spectrum_1.svg')
fig.show()

# %%
fig = visualize_power_spectrum('/home/users/jhischke/tuar_processed/train/aaaaagqb_s003_t002.edf', 'T4-A2')
fig.savefig('./output/exp_02_04_power_spectrum_2.svg')
fig.show()

# %%
fig = visualize_power_spectrum('/home/users/jhischke/tuar_processed/train/aaaaadao_s001_t003.edf', 'CZ-C4')
fig.savefig('./output/exp_02_04_power_spectrum_3.svg')
fig.show()

# %%
fig = visualize_power_spectrum('/home/users/jhischke/tuar_processed/test/aaaaacyf_s007_t002.edf', 'P4-O2', ylim=(10e-4, 10e2))
fig.savefig('./output/exp_02_04_power_spectrum_4.svg')
fig.show()

# %% [markdown]
# - Bemerkungen
#     - Bei der letzten Grafik fängt die y Achse weiter unten an. Sonst würde man das meiste des Graphen nicht sehen.
#
# - Notizen
#     - Auch hier ist es wieder spannend, solche Graphen zum ersten Mal zu sehen.
#     - Die Gesamttendenz scheint zu sein, dass die Intensität der Schwingungen mit steigender Frequenz abnimmt, was sich mit Herr Bialonskis Aussage (1-über-f-Verlauf) deckt.
